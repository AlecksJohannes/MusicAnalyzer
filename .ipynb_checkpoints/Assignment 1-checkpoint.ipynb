# %%
import pandas as pd
import numpy as np

# %%
genres_dataset = pd.read_json('MasterSongList.json')

# %%
genres_dataset.head(10)
# Out:
#                                     _id  \
# 0  {'$oid': '52fdfb440b9398049f3d7a8c'}
# 1  {'$oid': '52fdfb3d0b9398049f3cbc8e'}
# 2  {'$oid': '52fdfb420b9398049f3d3ea5'}
# 3  {'$oid': '52fdfb410b9398049f3d1eac'}
# 4  {'$oid': '52fdfb400b9398049f3d0b19'}
# 5  {'$oid': '52fdfb3e0b9398049f3cdd7f'}
# 6  {'$oid': '52fdfb3f0b9398049f3ce0f0'}
# 7  {'$oid': '52fdfb440b9398049f3d7a7d'}
# 8  {'$oid': '52fdfb400b9398049f3d0d47'}
# 9  {'$oid': '52fdfb400b9398049f3d0dc7'}
#
#                                          album            artist  \
# 0                        Gangnam Style (강남스타일)               PSY
# 1                                       Native       OneRepublic
# 2                            Party Rock Anthem             LMFAO
# 3                                    Gentleman               PSY
# 4                                 On The Floor    Jennifer Lopez
# 5                                The Lazy Song        Bruno Mars
# 6                          Rolling In The Deep             Adele
# 7                                Call Me Maybe  Carly Rae Jepsen
# 8  Somebody That I Used To Know (Feat. Kimbra)             Gotye
# 9                     What Makes You Beautiful     One Direction
#
#                                       audio_features  \
# 0  [11, 0.912744, 0.083704, 132.069, 0.293137, 0....
# 1  [6, 0.7457039999999999, 0.11995499999999999, 1...
# 2  [5, 0.709932, 0.231455, 130.03, 0.121740999999...
# 3  [3, 0.705822, 0.053292, 126.009, 0.126016, 0.0...
# 4  [3, 0.741757, 0.07277399999999999, 129.985, 0....
# 5  [8, 0.733856, 0.093043, 174.952, 0.05813699999...
# 6  [8, 0.7773749999999999, 0.054104, 104.946, 0.0...
# 7  [7, 0.585564, 0.10829699999999999, 120.014, 0....
# 8  [0, 0.418212, 0.105322, 129.054, 0.045461, 0.5...
# 9  [4, 0.81403, 0.079196, 124.991, 0.07244, 0.005...
#
#                                              context  decades       genres  \
# 0                                         [work out]       []        [pop]
# 1                                        [energetic]   [2012]        [pop]
# 2       [energetic, energetic, energetic, energetic]       []           []
# 3         [party, party, party, party, party, party]  [2010s]      [dance]
# 4                                     [party, party]  [2000s]  [reggaeton]
# 5                                     [just woke up]       []           []
# 6                              [relax, relax, relax]       []  [r&b: soul]
# 7                                         [work out]       []        [pop]
# 8                                 [candlelit dinner]       []           []
# 9  [studying / working, studying / working, study...  [2010s]        [pop]
#
#                                      lyrics_features  \
# 0  [oppa, gangnam, style, gangnam, style, najeneu...
# 1  [lately, i, ve, been, i, ve, been, losing, sle...
# 2  [party, rock, yeah, woo, let, s, go, party, ro...
# 3  [alagamun, lan, weh, wakun, heya, hanun, gon, ...
# 4  [j, lo, the, other, side, out, my, mine, it, s...
# 5  [today, i, don, t, feel, like, doing, anything...
# 6  [there, s, a, fire, starting, in, my, heart, r...
# 7  [i, threw, a, wish, in, the, well, don, t, ask...
# 8  [now, and, then, i, think, of, when, we, were,...
# 9  [don, t, know, what, for, you, re, turning, he...
#
#                              moods  \
# 0        [energetic, motivational]
# 1                          [happy]
# 2      [happy, celebratory, rowdy]
# 3  [happy, energetic, celebratory]
# 4                      [energetic]
# 5               [happy, sprightly]
# 6                           [warm]
# 7        [energetic, motivational]
# 8           [seductive, nocturnal]
# 9             [happy, celebratory]
#
#                                           name       new_context  \
# 0                        Gangnam Style (강남스타일)          work out
# 1                               Counting Stars         energetic
# 2                            Party Rock Anthem         housework
# 3                                    Gentleman         energetic
# 4                                 On The Floor          work out
# 5                                The Lazy Song      just woke up
# 6                          Rolling In The Deep          chillout
# 7                                Call Me Maybe          work out
# 8  Somebody That I Used To Know (Feat. Kimbra)  candlelit dinner
# 9                     What Makes You Beautiful         housework
#
#                                              picture  recording_id  \
# 0  http://images.musicnet.com/albums/073/463/405/...       50232.0
# 1  http://images.musicnet.com/albums/081/851/887/...        5839.0
# 2  http://images.musicnet.com/albums/049/414/127/...       52379.0
# 3  http://images.musicnet.com/albums/082/950/461/...       12353.0
# 4  http://images.musicnet.com/albums/050/131/765/...       29502.0
# 5  http://images.musicnet.com/albums/051/655/149/...       46206.0
# 6  http://images.musicnet.com/albums/047/744/109/...        9154.0
# 7  http://images.musicnet.com/albums/064/604/149/...       35484.0
# 8  http://images.musicnet.com/albums/056/945/335/...       41786.0
# 9  http://images.musicnet.com/albums/064/019/497/...       20475.0
#
#                                          sub_context        yt_id    yt_views
# 0                              [working out: cardio]  9bZkp7q19f0  2450112089
# 1                                     [energy boost]  hT_nvWreIhg  1020297206
# 2  [energy boost, pleasing a crowd, housework, dr...  KQ6zr6kCPj8   971128436
# 3  [driving in the left lane, energy boost, girls...  ASO_zypdnsQ   892096527
# 4         [working out: cardio, dance party: sweaty]  t4H_Zoh7G5A   873285189
# 5           [waking up on the right side of the bed]  fLexgOxsZu0   775630683
# 6  [pleasing a crowd, lying low on a sunday after...  rYEDA3JcQqw   745960922
# 7                              [working out: cardio]  fWNaR-rxAic   743689468
# 8                                 [romantic evening]  8UVNT4wvIGY   702996459
# 9  [energy boost, pleasing a crowd, housework, wo...  QJO3ROT-A4E   697513708

# %%
## Preprocessing data and categorise 

def preprocess_data():
    global filtered_genres_dataset
    genres_dataset.loc[:, 'genres'] = genres_dataset['genres'].apply(''.join)
    genres_dataset.loc[:, 'genres'] = genres_dataset['genres'].apply(consolidate_genre)
    
    dance_dataset = genres_dataset.loc[(genres_dataset['genres'] == 'dance')].sample(n=2000)
    jazz_dataset = genres_dataset.loc[(genres_dataset['genres'] == 'jazz')].sample(n=2000)
    country_dataset = genres_dataset.loc[(genres_dataset['genres'] == 'country')].sample(n=1200)
    filtered_genres_dataset = pd.concat([dance_dataset, jazz_dataset, country_dataset])
                             
def consolidate_genre(genre):
    if (len(genre) > 0):
        return genre.split(':')[0]
    else:
        return genre
    
preprocess_data()

# %%
filtered_genres_dataset.head(10)
# Out:
#                                         _id                            album  \
# 36511  {'$oid': '52fdfb410b9398049f3d1da5'}                          Plugged
# 3905   {'$oid': '52fdfb460b9398049f3da24c'}                        Discovery
# 8089   {'$oid': '52fdfb460b9398049f3da3e5'}                 Reggae Gold 2004
# 20126  {'$oid': '52fdfb400b9398049f3cfc6c'}              Scratch Marchin' EP
# 34625  {'$oid': '52fdfb410b9398049f3d1d6d'}  A Splendor In The Grass Sampler
# 31332  {'$oid': '52fdfb3f0b9398049f3ce522'}             The Future Will Come
# 19316  {'$oid': '52fdfb410b9398049f3d2926'}                            Blau!
# 14675  {'$oid': '52fdfb430b9398049f3d4c6d'}                          Circles
# 2076   {'$oid': '52fdfb3d0b9398049f3cc7cf'}                       Need In Me
# 31749  {'$oid': '52fdfb470b9398049f3daea0'}      Children Of The Night/Zatla
#
#                      artist  \
# 36511      Mental Overdrive
# 3905              Daft Punk
# 8089             Beenie Man
# 20126                Kormac
# 34625  Filipsson & Lindblad
# 31332          Juan Maclean
# 19316         Laidback Luke
# 14675            Digitalism
# 2076               Flashmob
# 31749                 Tegma
#
#                                           audio_features  \
# 36511                                                 []
# 3905   [5, 0.5829700000000001, 0.19063000000000002, 1...
# 8089   [5, 0.671504, 0.210581, 94.038, 0.293247, 0.19...
# 20126                                                 []
# 34625  [8, 0.654073, 0.12956499999999999, 112.006, 0....
# 31332  [10, 0.9579529999999999, 0.253528, 124.977, 0....
# 19316  [0, 0.47457499999999997, 0.076413, 129.005, 0....
# 14675  [11, 0.929044, 0.153148, 140.03, 0.363272, 0.0...
# 2076   [8, 0.9164169999999999, 0.047538, 120.013, 0.0...
# 31749                                                 []
#
#                                    context            decades genres  \
# 36511                       [party, party]            [2000s]  dance
# 3905          [party, party, party, party]  ['00s electronic]  dance
# 8089   [party, party, party, party, party]            [2010s]  dance
# 20126                           [chillout]             [2012]  dance
# 34625                       [party, party]            [2000s]  dance
# 31332               [staying up all night]  ['00s electronic]  dance
# 19316                       [party, party]            [2000s]  dance
# 14675                              [party]                 []  dance
# 2076                  [studying / working]             [2012]  dance
# 31749                [party, party, party]            [2000s]  dance
#
#                                          lyrics_features  \
# 36511                                                 []
# 3905   [it, s, been, much, too, long, i, feel, it, co...
# 8089   [you, want, a, proper, fix, call, me, you, wan...
# 20126                                                 []
# 34625                                                 []
# 31332  [promises, you, gave, but, never, kept, apolog...
# 19316                                                 []
# 14675  [gather, all, the, good, times, when, they, ch...
# 2076                                                  []
# 31749                                                 []
#
#                               moods                                     name  \
# 36511             [energetic, cold]  Please Hold On Featuring Anneli Drecker
# 3905          [energetic, visceral]                                 Too Long
# 8089              [cocky, visceral]  Dude (Remix) (Feat. Ms Thing & Shawwna)
# 20126                   [sprightly]                   Harry's Record Machine
# 34625             [energetic, cold]                             Another Plan
# 31332  [energetic, cold, nocturnal]                          The Simple Life
# 19316      [visceral, motivational]                   Blau! (LA Riots Remix)
# 14675                       [cocky]             Circles (Dillon Francis Rmx)
# 2076           [hypnotic, visceral]                               Need In Me
# 31749                    [hypnotic]                                    Zatla
#
#               new_context                                            picture  \
# 36511               party  http://images.musicnet.com/albums/029/652/085/...
# 3905               coding  http://images.musicnet.com/albums/000/091/851/...
# 8089             work out  http://images.musicnet.com/albums/016/217/957/...
# 20126            chillout  http://images.musicnet.com/albums/011/846/803/...
# 34625               party  http://images.musicnet.com/albums/031/352/605/...
# 31332                 NaN  http://images.musicnet.com/albums/028/069/163/...
# 19316              coding  http://images.musicnet.com/albums/035/246/779/...
# 14675               party  http://images.musicnet.com/albums/061/527/033/...
# 2076   studying / working  http://images.musicnet.com/albums/067/322/307/...
# 31749              coding  http://images.musicnet.com/albums/012/253/863/...
#
#        recording_id                                        sub_context  \
# 36511       65569.0        [staying up all night, dance party: sweaty]
# 3905        76320.0  [driving in the left lane, dance party: sweaty...
# 8089        46058.0  [grinding at a nightclub, working out: weight ...
# 20126       16131.0                                   [cocktail party]
# 34625       65534.0        [staying up all night, dance party: sweaty]
# 31332       58539.0                                                NaN
# 19316           NaN                      [dance party: sweaty, coding]
# 14675           NaN                          [grinding at a nightclub]
# 2076        54628.0                   [working/studying (with lyrics)]
# 31749       48756.0  [working out: cardio, dance party: sweaty, cod...
#
#              yt_id  yt_views
# 36511  mmS58uOMhUo        67
# 3905   Z6_ZNW1DACE   3272430
# 8089   Z_P0J9L00XI    739786
# 20126  qCkt9VIoqyI     45502
# 34625  rXg3raRgFPc       818
# 31332  7PAhNIxkUck      3195
# 19316  ExXmUOWSktw     53550
# 14675  Oy23u7-PwZg    143885
# 2076   ibCvMVFKh1w   9282050
# 31749  eLlPlIMBbFM      2789

# %%
### Setting up data frame
audio_feature_headers = ['key', 
                         'energy', 
                         'liveliness', 
                         'tempo', 
                         'speechiness', 
                         'acousticness', 
                         'instrumentalness', 
                         'time_signature', 
                         'duration', 
                         'loudness', 
                         'valence', 
                         'danceability', 
                         'mode', 
                         'time_signature_confidence', 
                         'tempo_confidence', 
                         'key_confidence', 
                         'mode_confidence',
                         'moods',
                         'new_context',
                        ] 
audio_features_list = []
for audio_feature in filtered_genres_dataset['audio_features']:
    audio_features_list.append(audio_feature)

for index, mood in enumerate(filtered_genres_dataset['moods']):
    audio_features_list[index].append(mood)
    
for index, context in enumerate(filtered_genres_dataset['new_context']):
    audio_features_list[index].append(context)
    
df_features = pd.DataFrame(audio_features_list, columns=audio_feature_headers)

# %%
filtered_genres_dataset['genres'].reset_index(drop=True, inplace=True)
df_features['genres'] = filtered_genres_dataset['genres']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

df_features.dropna(inplace=True)
df_features['moods'] = label_encoder.fit_transform(df_features['moods'])
df_features['new_context'] = label_encoder.fit_transform(df_features['new_context'])
labels_finals = df_features['genres']
df_features = df_features.drop(['genres', 
                                'mode_confidence',
                                'time_signature',
                                'duration',
                                'time_signature_confidence', 
                                'tempo',
                                'speechiness', 
                                'key', 
                                'key_confidence',
                                'tempo_confidence',
                                'liveliness',
                                'valence',
                                'instrumentalness',
                               ], axis=1)

# %%
df_features.head(5)
# Out:
#      energy  acousticness   loudness  danceability      mode  moods  \
# 1   0.58297      0.002131  600.29333      0.510325  0.657644     34
# 2  0.671504      0.196514  251.68000      0.943340  0.710542     21
# 4  0.654073      0.001609  514.55420      0.655612  0.827610     29
# 6  0.474575      0.006443  366.56952      0.297432  0.755322     66
# 7  0.929044      0.004028  225.81333      0.358122  0.438358     19
#
#    new_context
# 1            3
# 2           17
# 4           12
# 6            3
# 7           12

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
df_scaled_features = standard_scaler.fit_transform(df_features)

audio_feature_headers = [
                         'acousticness',
                         'mode',
                         'danceability',
                         'energy', 
                         'loudness',
                         'moods',
                         'new_context',
                         ]
df_features_final = pd.DataFrame(df_scaled_features, columns=audio_feature_headers)

# %%
from sklearn.model_selection import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(algorithm='auto', leaf_size=30,
           metric_params=None, n_jobs=1, n_neighbors=3, p=2)

X_train, X_test, y_train, y_test = train_test_split(df_features_final,
                                                    labels_finals, 
                                                    test_size = 0.33, 
                                                    random_state = 101)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
np.mean(cross_val_score(knn, df_features_final, labels_finals, cv=10))
# Out:
# /anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# 0.92130486840916659

# %%
# Evaluate accuracy
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from nltk import ConfusionMatrix
print(ConfusionMatrix(list(y_test), list(pred)))
print(accuracy_score(y_test, pred))
print(classification_report(y_test, pred))
# Out:
#         |   c         |
#         |   o         |
#         |   u   d     |
#         |   n   a   j |
#         |   t   n   a |
#         |   r   c   z |
#         |   y   e   z |
# --------+-------------+
# country |<188>  9  11 |
#   dance |  20<254>  5 |
#    jazz |  18   7<293>|
# --------+-------------+
# (row = reference; col = test)
#
# 0.913043478261
#              precision    recall  f1-score   support
#
#     country       0.83      0.90      0.87       208
#       dance       0.94      0.91      0.93       279
#        jazz       0.95      0.92      0.93       318
#
# avg / total       0.92      0.91      0.91       805

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ###
